# %%
### IMPORT SCIENTIFIC LIBRARIES ###
import numpy as np
import pandas as pd
from scipy import sparse
from scipy.optimize import curve_fit
import lmfit as lm
from tqdm import tqdm
from contextlib import redirect_stdout
import io


import matplotlib.pyplot as plt
plt.rcParams['font.size'], plt.rcParams['axes.labelsize'] = 14, 18
import sys, importlib

import sys
sys.path.append('./XPCSlibrary/')

import ID10_tools as ID10
from ID10_tools import Nx, Ny, Npx
importlib.reload(ID10)
ID10.set_version('v2')

import XPCS_tools as XPCS
from XPCS_tools import E2lambda, lambda2E, theta2Q, Q2theta, decorrelation_f
importlib.reload(XPCS)
XPCS.set_beamline('ID10')

import COSMICRAY_tools as COSMIC
importlib.reload(COSMIC)
COSMIC.set_beamline('ID10')

### EXPERIMENTAL VARIABLES ###
XPCS.set_expvar(Nx//2, Ny//2, 5)
ID10.Nfmax_dense_file = 2000
ID10.Nfmax_sparse_file = 5000

from folder_paths import *

# %% [markdown]
# ## Load masks

# %%
e4m_mask = np.load(MASKS_folder+'e4m_mask'+'.npy')
e4m_htmask = np.load(MASKS_folder+'e4m_htmask_Mo_fluorescence'+'.npy')

plt.figure(figsize=(6, 6))
plt.imshow((e4m_mask*e4m_htmask).reshape(Nx,Ny), cmap='gray', origin='lower')
plt.xlabel('Y [px]')
plt.ylabel('X [px]')
plt.tight_layout(); plt.show()

# %%
pilatus_mask = np.load(MASKS_folder+'pilatus300k_mask_20240201'+'.npy').astype(bool)

plt.figure(figsize=(6, 6))
plt.imshow(~pilatus_mask, cmap='gray', origin='lower')
plt.xlabel('Y [px]')
plt.ylabel('X [px]')
plt.tight_layout(); plt.show()

# %% [markdown]
# ## Q mask

# %%
###########
Q = 0.57
dq = 0.01
###########
Q=float(Q)

# %% [markdown]
# ## XPCS scan: delcoup=3.5, T=4h (Ta2O5_2.5um_asdep, 4, 6)
#
# Tantala as deposited

# %%
#######################################
sample_name = 'Ta2O5_2.5um_asdep'
Ndataset = 4
Nscan = 6
#######################################

scan = ID10.load_scan(RAW_folder, sample_name, Ndataset, Nscan)
Ei = scan['monoe']
itime = scan['fast_timer_period'][0]
T = scan['fast_timer_period'].size*itime
theta = scan['delcoup']
Qc = round(XPCS.theta2Q(Ei,  theta),2)

print('#############################')
print('command =', scan['command'])
print('Ei =', Ei)
print('itime =', itime)
print('T = ', T/60**2, 'h')
print('theta =', theta)
print('Qc =', Qc)
print('#############################\n')

#################################################################################
Nfi, Nff = None, len(scan['fast_timer_trig'])-5001
Qmask = XPCS.gen_Qmask(Ei, theta, Q, dq, Qmap_plot=False)
Kossel_mask = np.load(MASKS_folder+'Kossel_mask_Ta2O5_2.5um_asdep_0002_0001.npy')
load_mask = e4m_mask*e4m_htmask*Qmask#*Kossel_mask
##################################################################################

e4m_data = ID10.load_sparse_e4m(RAW_folder, sample_name, Ndataset, Nscan, Nfi=Nfi, Nff=Nff, load_mask=load_mask, n_jobs=50, )
# Out:
# #############################
# command = mtimescan 0.001 1 16000128
# Ei = 21.669991317784486
# itime = 0.0011
# T =  4.001339833333334 h
# theta = 3.499999999999999
# Qc = 0.67
# #############################
# Loading sparse array ...
# 	 -> loading file eiger4m_v2_sparse_frame_0_00001.h5 (2/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00003.h5 (4/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00013.h5 (14/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00004.h5 (5/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00000.h5 (1/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00002.h5 (3/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00012.h5 (13/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00011.h5 (12/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00005.h5 (6/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00050.h5 (51/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00051.h5 (52/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00007.h5 (8/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00010.h5 (11/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00052.h5 (53/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00008.h5 (9/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00053.h5 (54/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00009.h5 (10/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00054.h5 (55/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00055.h5 (56/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00056.h5 (57/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00057.h5 (58/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00058.h5 (59/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00006.h5 (7/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00059.h5 (60/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00060.h5 (61/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00061.h5 (62/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00062.h5 (63/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00063.h5 (64/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00064.h5 (65/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00065.h5 (66/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00066.h5 (67/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00067.h5 (68/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00068.h5 (69/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00069.h5 (70/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00070.h5 (71/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00071.h5 (72/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00072.h5 (73/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00073.h5 (74/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00074.h5 (75/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00075.h5 (76/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00076.h5 (77/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00077.h5 (78/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00078.h5 (79/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00079.h5 (80/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00080.h5 (81/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00081.h5 (82/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00082.h5 (83/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00083.h5 (84/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00084.h5 (85/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00085.h5 (86/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00086.h5 (87/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00087.h5 (88/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00088.h5 (89/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00089.h5 (90/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00090.h5 (91/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00091.h5 (92/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00092.h5 (93/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00093.h5 (94/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00094.h5 (95/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00095.h5 (96/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00096.h5 (97/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00097.h5 (98/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00098.h5 (99/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00099.h5 (100/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00100.h5 (101/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00101.h5 (102/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00102.h5 (103/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00014.h5 (15/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00103.h5 (104/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00104.h5 (105/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00105.h5 (106/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00106.h5 (107/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00107.h5 (108/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00108.h5 (109/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00109.h5 (110/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00110.h5 (111/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00111.h5 (112/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00112.h5 (113/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00113.h5 (114/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00114.h5 (115/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00115.h5 (116/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00116.h5 (117/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00117.h5 (118/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00118.h5 (119/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00119.h5 (120/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00120.h5 (121/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00121.h5 (122/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00122.h5 (123/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00123.h5 (124/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00124.h5 (125/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00125.h5 (126/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00126.h5 (127/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00127.h5 (128/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00128.h5 (129/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00129.h5 (130/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00130.h5 (131/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00131.h5 (132/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00132.h5 (133/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00133.h5 (134/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00134.h5 (135/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00135.h5 (136/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00136.h5 (137/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00137.h5 (138/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00138.h5 (139/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00139.h5 (140/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00140.h5 (141/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00141.h5 (142/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00142.h5 (143/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00143.h5 (144/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00015.h5 (16/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00016.h5 (17/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00144.h5 (145/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00145.h5 (146/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00146.h5 (147/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00147.h5 (148/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00148.h5 (149/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00149.h5 (150/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00150.h5 (151/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00151.h5 (152/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00152.h5 (153/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00153.h5 (154/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00154.h5 (155/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00155.h5 (156/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00156.h5 (157/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00157.h5 (158/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00158.h5 (159/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00159.h5 (160/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00160.h5 (161/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00017.h5 (18/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00161.h5 (162/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00162.h5 (163/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00163.h5 (164/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00164.h5 (165/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00165.h5 (166/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00166.h5 (167/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00167.h5 (168/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00168.h5 (169/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00169.h5 (170/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00170.h5 (171/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00171.h5 (172/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00172.h5 (173/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00173.h5 (174/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00174.h5 (175/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00175.h5 (176/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00176.h5 (177/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00177.h5 (178/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00178.h5 (179/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00179.h5 (180/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00180.h5 (181/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00181.h5 (182/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00182.h5 (183/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00183.h5 (184/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00184.h5 (185/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00185.h5 (186/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00186.h5 (187/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00019.h5 (20/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00187.h5 (188/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00188.h5 (189/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00189.h5 (190/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00190.h5 (191/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00018.h5 (19/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00191.h5 (192/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00192.h5 (193/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00193.h5 (194/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00194.h5 (195/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00195.h5 (196/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00196.h5 (197/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00197.h5 (198/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00198.h5 (199/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00199.h5 (200/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00200.h5 (201/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00201.h5 (202/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00202.h5 (203/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00203.h5 (204/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00204.h5 (205/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00205.h5 (206/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00206.h5 (207/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00207.h5 (208/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00208.h5 (209/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00209.h5 (210/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00210.h5 (211/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00211.h5 (212/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00212.h5 (213/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00213.h5 (214/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00214.h5 (215/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00215.h5 (216/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00216.h5 (217/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00217.h5 (218/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00218.h5 (219/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00219.h5 (220/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00220.h5 (221/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00221.h5 (222/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00222.h5 (223/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00223.h5 (224/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00224.h5 (225/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00225.h5 (226/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00226.h5 (227/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00227.h5 (228/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00228.h5 (229/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00229.h5 (230/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00230.h5 (231/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00231.h5 (232/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00232.h5 (233/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00233.h5 (234/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00234.h5 (235/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00235.h5 (236/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00236.h5 (237/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00237.h5 (238/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00238.h5 (239/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00239.h5 (240/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00241.h5 (242/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00240.h5 (241/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00242.h5 (243/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00243.h5 (244/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00244.h5 (245/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00245.h5 (246/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00246.h5 (247/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00247.h5 (248/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00248.h5 (249/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00249.h5 (250/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00250.h5 (251/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00251.h5 (252/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00252.h5 (253/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00253.h5 (254/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00254.h5 (255/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00021.h5 (22/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00255.h5 (256/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00256.h5 (257/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00257.h5 (258/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00258.h5 (259/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00259.h5 (260/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00260.h5 (261/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00261.h5 (262/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00262.h5 (263/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00263.h5 (264/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00264.h5 (265/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00265.h5 (266/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00266.h5 (267/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00020.h5 (21/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00267.h5 (268/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00268.h5 (269/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00269.h5 (270/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00270.h5 (271/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00271.h5 (272/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00272.h5 (273/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00273.h5 (274/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00274.h5 (275/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00275.h5 (276/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00276.h5 (277/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00277.h5 (278/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00278.h5 (279/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00279.h5 (280/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00280.h5 (281/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00281.h5 (282/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00282.h5 (283/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00283.h5 (284/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00284.h5 (285/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00285.h5 (286/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00286.h5 (287/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00287.h5 (288/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00022.h5 (23/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00288.h5 (289/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00289.h5 (290/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00290.h5 (291/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00291.h5 (292/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00292.h5 (293/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00293.h5 (294/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00294.h5 (295/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00295.h5 (296/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00296.h5 (297/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00297.h5 (298/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00298.h5 (299/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00299.h5 (300/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00300.h5 (301/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00301.h5 (302/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00302.h5 (303/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00303.h5 (304/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00304.h5 (305/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00305.h5 (306/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00306.h5 (307/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00307.h5 (308/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00023.h5 (24/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00308.h5 (309/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00025.h5 (26/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00309.h5 (310/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00310.h5 (311/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00311.h5 (312/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00312.h5 (313/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00313.h5 (314/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00314.h5 (315/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00315.h5 (316/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00316.h5 (317/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00317.h5 (318/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00318.h5 (319/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00024.h5 (25/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00319.h5 (320/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00027.h5 (28/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00320.h5 (321/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00026.h5 (27/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00321.h5 (322/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00322.h5 (323/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00323.h5 (324/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00324.h5 (325/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00325.h5 (326/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00326.h5 (327/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00327.h5 (328/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00328.h5 (329/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00029.h5 (30/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00329.h5 (330/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00330.h5 (331/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00331.h5 (332/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00332.h5 (333/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00333.h5 (334/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00334.h5 (335/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00335.h5 (336/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00030.h5 (31/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00336.h5 (337/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00032.h5 (33/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00337.h5 (338/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00028.h5 (29/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00338.h5 (339/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00339.h5 (340/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00340.h5 (341/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00341.h5 (342/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00342.h5 (343/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00343.h5 (344/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00031.h5 (32/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00344.h5 (345/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00345.h5 (346/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00033.h5 (34/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00346.h5 (347/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00034.h5 (35/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00347.h5 (348/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00348.h5 (349/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00349.h5 (350/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00350.h5 (351/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00036.h5 (37/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00351.h5 (352/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00352.h5 (353/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00037.h5 (38/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00353.h5 (354/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00354.h5 (355/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00355.h5 (356/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00035.h5 (36/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00356.h5 (357/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00040.h5 (41/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00357.h5 (358/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00039.h5 (40/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00358.h5 (359/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00359.h5 (360/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00038.h5 (39/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00360.h5 (361/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00046.h5 (47/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00043.h5 (44/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00044.h5 (45/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00042.h5 (43/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00361.h5 (362/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00049.h5 (50/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00041.h5 (42/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00045.h5 (46/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00047.h5 (48/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00048.h5 (49/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00362.h5 (363/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00363.h5 (364/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00364.h5 (365/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00365.h5 (366/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00366.h5 (367/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00367.h5 (368/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00368.h5 (369/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00369.h5 (370/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00370.h5 (371/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00371.h5 (372/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00372.h5 (373/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00373.h5 (374/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00374.h5 (375/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00375.h5 (376/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00376.h5 (377/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00377.h5 (378/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00378.h5 (379/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00379.h5 (380/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00380.h5 (381/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00381.h5 (382/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00382.h5 (383/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00383.h5 (384/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00384.h5 (385/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00385.h5 (386/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00386.h5 (387/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00387.h5 (388/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00388.h5 (389/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00389.h5 (390/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00390.h5 (391/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00391.h5 (392/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00392.h5 (393/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00393.h5 (394/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00394.h5 (395/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00395.h5 (396/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00396.h5 (397/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00397.h5 (398/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00398.h5 (399/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00399.h5 (400/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00400.h5 (401/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00401.h5 (402/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00402.h5 (403/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00403.h5 (404/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00404.h5 (405/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00405.h5 (406/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00406.h5 (407/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00407.h5 (408/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00408.h5 (409/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00409.h5 (410/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00410.h5 (411/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00411.h5 (412/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00412.h5 (413/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00413.h5 (414/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00414.h5 (415/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00415.h5 (416/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00416.h5 (417/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00417.h5 (418/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00418.h5 (419/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00419.h5 (420/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00420.h5 (421/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00421.h5 (422/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00422.h5 (423/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00423.h5 (424/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00424.h5 (425/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00425.h5 (426/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00426.h5 (427/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00427.h5 (428/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00428.h5 (429/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00429.h5 (430/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00430.h5 (431/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00431.h5 (432/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00432.h5 (433/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00433.h5 (434/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00434.h5 (435/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00435.h5 (436/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00436.h5 (437/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00437.h5 (438/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00438.h5 (439/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00439.h5 (440/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00440.h5 (441/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00441.h5 (442/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00442.h5 (443/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00443.h5 (444/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00444.h5 (445/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00445.h5 (446/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00446.h5 (447/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00447.h5 (448/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00448.h5 (449/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00449.h5 (450/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00450.h5 (451/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00451.h5 (452/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00452.h5 (453/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00453.h5 (454/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00454.h5 (455/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00455.h5 (456/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00456.h5 (457/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00457.h5 (458/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00458.h5 (459/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00459.h5 (460/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00460.h5 (461/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00461.h5 (462/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00462.h5 (463/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00463.h5 (464/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00464.h5 (465/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00465.h5 (466/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00466.h5 (467/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00467.h5 (468/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00468.h5 (469/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00469.h5 (470/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00470.h5 (471/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00471.h5 (472/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00472.h5 (473/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00473.h5 (474/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00474.h5 (475/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00475.h5 (476/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00476.h5 (477/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00477.h5 (478/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00478.h5 (479/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00479.h5 (480/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00480.h5 (481/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00481.h5 (482/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00482.h5 (483/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00483.h5 (484/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00484.h5 (485/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00485.h5 (486/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00486.h5 (487/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00487.h5 (488/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00488.h5 (489/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00489.h5 (490/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00490.h5 (491/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00491.h5 (492/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00492.h5 (493/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00493.h5 (494/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00494.h5 (495/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00495.h5 (496/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00496.h5 (497/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00497.h5 (498/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00498.h5 (499/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00499.h5 (500/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00500.h5 (501/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00501.h5 (502/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00502.h5 (503/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00503.h5 (504/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00504.h5 (505/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00505.h5 (506/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00506.h5 (507/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00507.h5 (508/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00508.h5 (509/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00509.h5 (510/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00510.h5 (511/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00511.h5 (512/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00512.h5 (513/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00513.h5 (514/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00514.h5 (515/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00515.h5 (516/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00516.h5 (517/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00517.h5 (518/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00518.h5 (519/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00519.h5 (520/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00520.h5 (521/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00521.h5 (522/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00522.h5 (523/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00523.h5 (524/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00524.h5 (525/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00525.h5 (526/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00526.h5 (527/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00527.h5 (528/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00528.h5 (529/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00529.h5 (530/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00530.h5 (531/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00531.h5 (532/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00532.h5 (533/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00533.h5 (534/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00534.h5 (535/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00535.h5 (536/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00536.h5 (537/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00537.h5 (538/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00538.h5 (539/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00539.h5 (540/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00540.h5 (541/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00541.h5 (542/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00542.h5 (543/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00543.h5 (544/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00544.h5 (545/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00545.h5 (546/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00546.h5 (547/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00547.h5 (548/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00548.h5 (549/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00549.h5 (550/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00550.h5 (551/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00551.h5 (552/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00552.h5 (553/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00553.h5 (554/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00554.h5 (555/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00555.h5 (556/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00556.h5 (557/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00557.h5 (558/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00558.h5 (559/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00559.h5 (560/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00560.h5 (561/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00561.h5 (562/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00562.h5 (563/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00563.h5 (564/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00564.h5 (565/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00565.h5 (566/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00566.h5 (567/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00567.h5 (568/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00568.h5 (569/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00569.h5 (570/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00570.h5 (571/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00571.h5 (572/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00572.h5 (573/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00573.h5 (574/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00574.h5 (575/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00575.h5 (576/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00576.h5 (577/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00577.h5 (578/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00578.h5 (579/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00579.h5 (580/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00580.h5 (581/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00581.h5 (582/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00582.h5 (583/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00583.h5 (584/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00584.h5 (585/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00585.h5 (586/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00586.h5 (587/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00587.h5 (588/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00588.h5 (589/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00589.h5 (590/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00590.h5 (591/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00591.h5 (592/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00592.h5 (593/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00593.h5 (594/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00594.h5 (595/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00595.h5 (596/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00596.h5 (597/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00597.h5 (598/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00598.h5 (599/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00599.h5 (600/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00600.h5 (601/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00601.h5 (602/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00602.h5 (603/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00603.h5 (604/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00604.h5 (605/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00605.h5 (606/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00606.h5 (607/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00607.h5 (608/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00608.h5 (609/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00609.h5 (610/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00610.h5 (611/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00611.h5 (612/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00612.h5 (613/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00613.h5 (614/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00614.h5 (615/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00615.h5 (616/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00616.h5 (617/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00617.h5 (618/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00618.h5 (619/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00619.h5 (620/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00620.h5 (621/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00621.h5 (622/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00622.h5 (623/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00623.h5 (624/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00624.h5 (625/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00625.h5 (626/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00626.h5 (627/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00627.h5 (628/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00628.h5 (629/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00629.h5 (630/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00630.h5 (631/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00631.h5 (632/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00632.h5 (633/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00633.h5 (634/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00634.h5 (635/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00635.h5 (636/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00636.h5 (637/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00637.h5 (638/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00638.h5 (639/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00639.h5 (640/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00640.h5 (641/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00641.h5 (642/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00642.h5 (643/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00643.h5 (644/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00644.h5 (645/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00645.h5 (646/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00646.h5 (647/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00647.h5 (648/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00648.h5 (649/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00649.h5 (650/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00650.h5 (651/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00651.h5 (652/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00652.h5 (653/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00653.h5 (654/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00654.h5 (655/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00655.h5 (656/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00656.h5 (657/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00657.h5 (658/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00658.h5 (659/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00659.h5 (660/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00660.h5 (661/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00661.h5 (662/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00662.h5 (663/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00663.h5 (664/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00664.h5 (665/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00665.h5 (666/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00666.h5 (667/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00667.h5 (668/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00668.h5 (669/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00669.h5 (670/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00670.h5 (671/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00671.h5 (672/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00672.h5 (673/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00673.h5 (674/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00674.h5 (675/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00675.h5 (676/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00676.h5 (677/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00677.h5 (678/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00678.h5 (679/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00679.h5 (680/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00680.h5 (681/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00681.h5 (682/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00682.h5 (683/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00683.h5 (684/2618 loops)
# ...
# 	 -> loading file eiger4m_v2_sparse_frame_0_02398.h5 (2399/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_02399.h5 (2400/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_02400.h5 (2401/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_02401.h5 (2402/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_02402.h5 (2403/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_02403.h5 (2404/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_02404.h5 (2405/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_02405.h5 (2406/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_02406.h5 (2407/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_02407.h5 (2408/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_02408.h5 (2409/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_02409.h5 (2410/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_02410.h5 (2411/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_02411.h5 (2412/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_02412.h5 (2413/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_02413.h5 (2414/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_02414.h5 (2415/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_02415.h5 (2416/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_02416.h5 (2417/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_02417.h5 (2418/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_02418.h5 (2419/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_02419.h5 (2420/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_02420.h5 (2421/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_02421.h5 (2422/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_02422.h5 (2423/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_02423.h5 (2424/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_02424.h5 (2425/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_02425.h5 (2426/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_02426.h5 (2427/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_02427.h5 (2428/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_02428.h5 (2429/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_02429.h5 (2430/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_02430.h5 (2431/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_02431.h5 (2432/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_02432.h5 (2433/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_02433.h5 (2434/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_02434.h5 (2435/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_02435.h5 (2436/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_02436.h5 (2437/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_02437.h5 (2438/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_02438.h5 (2439/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_02439.h5 (2440/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_02440.h5 (2441/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_02441.h5 (2442/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_02442.h5 (2443/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_02443.h5 (2444/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_02444.h5 (2445/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_02445.h5 (2446/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_02446.h5 (2447/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_02447.h5 (2448/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_02448.h5 (2449/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_02449.h5 (2450/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_02450.h5 (2451/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_02451.h5 (2452/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_02452.h5 (2453/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_02453.h5 (2454/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_02454.h5 (2455/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_02455.h5 (2456/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_02456.h5 (2457/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_02457.h5 (2458/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_02458.h5 (2459/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_02459.h5 (2460/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_02460.h5 (2461/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_02461.h5 (2462/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_02462.h5 (2463/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_02463.h5 (2464/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_02464.h5 (2465/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_02465.h5 (2466/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_02466.h5 (2467/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_02467.h5 (2468/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_02468.h5 (2469/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_02469.h5 (2470/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_02470.h5 (2471/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_02471.h5 (2472/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_02472.h5 (2473/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_02473.h5 (2474/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_02474.h5 (2475/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_02475.h5 (2476/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_02476.h5 (2477/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_02477.h5 (2478/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_02478.h5 (2479/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_02479.h5 (2480/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_02480.h5 (2481/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_02481.h5 (2482/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_02482.h5 (2483/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_02483.h5 (2484/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_02484.h5 (2485/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_02485.h5 (2486/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_02486.h5 (2487/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_02487.h5 (2488/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_02488.h5 (2489/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_02489.h5 (2490/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_02490.h5 (2491/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_02491.h5 (2492/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_02492.h5 (2493/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_02493.h5 (2494/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_02494.h5 (2495/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_02495.h5 (2496/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_02496.h5 (2497/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_02497.h5 (2498/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_02498.h5 (2499/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_02499.h5 (2500/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_02500.h5 (2501/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_02501.h5 (2502/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_02502.h5 (2503/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_02503.h5 (2504/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_02504.h5 (2505/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_02505.h5 (2506/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_02506.h5 (2507/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_02507.h5 (2508/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_02508.h5 (2509/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_02509.h5 (2510/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_02510.h5 (2511/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_02511.h5 (2512/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_02512.h5 (2513/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_02513.h5 (2514/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_02514.h5 (2515/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_02515.h5 (2516/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_02516.h5 (2517/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_02517.h5 (2518/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_02518.h5 (2519/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_02519.h5 (2520/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_02520.h5 (2521/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_02521.h5 (2522/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_02522.h5 (2523/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_02523.h5 (2524/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_02524.h5 (2525/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_02525.h5 (2526/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_02526.h5 (2527/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_02527.h5 (2528/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_02528.h5 (2529/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_02529.h5 (2530/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_02530.h5 (2531/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_02531.h5 (2532/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_02532.h5 (2533/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_02533.h5 (2534/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_02534.h5 (2535/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_02535.h5 (2536/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_02536.h5 (2537/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_02537.h5 (2538/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_02538.h5 (2539/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_02539.h5 (2540/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_02540.h5 (2541/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_02541.h5 (2542/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_02542.h5 (2543/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_02543.h5 (2544/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_02544.h5 (2545/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_02545.h5 (2546/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_02546.h5 (2547/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_02547.h5 (2548/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_02548.h5 (2549/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_02549.h5 (2550/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_02550.h5 (2551/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_02551.h5 (2552/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_02552.h5 (2553/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_02553.h5 (2554/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_02554.h5 (2555/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_02555.h5 (2556/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_02556.h5 (2557/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_02557.h5 (2558/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_02558.h5 (2559/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_02559.h5 (2560/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_02560.h5 (2561/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_02561.h5 (2562/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_02562.h5 (2563/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_02563.h5 (2564/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_02564.h5 (2565/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_02565.h5 (2566/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_02566.h5 (2567/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_02567.h5 (2568/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_02568.h5 (2569/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_02569.h5 (2570/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_02570.h5 (2571/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_02571.h5 (2572/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_02572.h5 (2573/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_02573.h5 (2574/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_02574.h5 (2575/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_02575.h5 (2576/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_02576.h5 (2577/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_02577.h5 (2578/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_02578.h5 (2579/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_02579.h5 (2580/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_02580.h5 (2581/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_02581.h5 (2582/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_02582.h5 (2583/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_02583.h5 (2584/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_02584.h5 (2585/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_02585.h5 (2586/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_02586.h5 (2587/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_02587.h5 (2588/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_02588.h5 (2589/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_02589.h5 (2590/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_02590.h5 (2591/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_02591.h5 (2592/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_02592.h5 (2593/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_02593.h5 (2594/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_02594.h5 (2595/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_02595.h5 (2596/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_02596.h5 (2597/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_02597.h5 (2598/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_02598.h5 (2599/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_02600.h5 (2601/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_02599.h5 (2600/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_02601.h5 (2602/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_02602.h5 (2603/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_02603.h5 (2604/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_02604.h5 (2605/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_02605.h5 (2606/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_02606.h5 (2607/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_02607.h5 (2608/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_02608.h5 (2609/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_02609.h5 (2610/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_02610.h5 (2611/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_02611.h5 (2612/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_02612.h5 (2613/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_02613.h5 (2614/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_02614.h5 (2615/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_02615.h5 (2616/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_02616.h5 (2617/2618 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_02617.h5 (2618/2618 loops)
# Done! (elapsed time = 54.98 s)
# Concatenating vectors ...
# Done! (elapsed time = 1.29 s)
# 	 | Sparse array loaded from ../RAW_DATA/Ta2O5_2.5um_asdep/Ta2O5_2.5um_asdep_0004/scan0006/
# 	 | Shape:       (13087327, 213135)
# 	 | Sparsity:     1.4e-04
# 	 | Memory usage (scipy.csr_array): 4.497 GB (np.array usage: 10391.203 GB)

# %% [markdown]
# ### Flux check

# %%
XPCS.gen_plots4mask(e4m_data, itime, Ith_low=.33, Ith_high=0.45, Nfi=None, Nff=int(1e7), load_mask=load_mask, mask=None)
# Out:
# ################################################################################
# Maximum count in the whole run -> 3.0
# # of pixels above Ith_high treshold ->  4257881 pixels (of 4471016 => 95.23 %)
# # of pixels below Ith_low treshold ->  213135 pixels (of 4471016 => 4.77 %)
# ################################################################################

# %% [markdown]
# ### Intensity analysis

# %%
####################
Lbin = 500
Nstep = 1000
mask = None
Nfi = None
Nff = None
####################

t_It, It = XPCS.get_It(e4m_data, itime, mask=mask, Lbin=Lbin, Nstep=Nstep, Nfi=Nfi, Nff=Nff)
np.savez(It_folder+'Idt_'+sample_name+'_'+str(Ndataset).zfill(4)+'_'+str(Nscan).zfill(4)+'_Q='+str(Q)+'_dq='+str(dq), t_It=t_It, It=It)

# %%
plt.figure(figsize=(10,5))
plt.scatter(t_It, It, label='It')
plt.xlabel('Time (s)')
plt.ylabel('Integrated intensity [photons/pixel/s]')
plt.gca().secondary_xaxis('top', functions=(lambda x: x/itime, lambda x: x*itime))
#plt.xscale('log')
plt.show()

# %% [markdown]
# ### Linear correlation 4 tests

# %%
###################
Nfi = None
Nff = int(1e6)
Lbin = 1000
bin2dense = False
mask = None
###################
if Lbin is None: Lbin=1

G2t = XPCS.get_G2t(e4m_data, mask=mask, Nfi=Nfi, Nff=Nff, Lbin=Lbin, bin2dense=bin2dense)
# Out:
# Loading frames ...
# Done! (elapsed time = 0.11 s)
# Binning frames (Lbin = 1000, using MKL library) ...
# Done! (elapsed time = 0.1 s)
# 	 | 1000 frames X 213135 pixels
# 	 | sparsity = 1.28e-01
# 	 | memory usage (sparse.csr_array @ float32) = 0.305 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 1.54 s)
# 	 | 1000 X 1000 squared matrix
# 	 | memory usage (np.array @ float32) = 0.004 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.01 s)

# %%
############################
t1, t2 = 0, 3000
vmin, vmax = 1.0, 1.06
############################
XPCS.plot_G2t(G2t, vmin, vmax, itime*Lbin, t1=t1, t2=t2, sigma_filter=None)

# %%
################
Nbunch = 4
################

NfXbunch = int(G2t.shape[0]/Nbunch)
t, g2, dg2, t_mt, g2_mt = {}, {}, {}, {}, {}
for n in range(Nbunch):
    if Nfi is None: Nfi = 0
    t_bunch = Nfi*itime + round(itime*Lbin*NfXbunch*(n+1/2),1)

    if Nbunch!=1: t[t_bunch], g2[t_bunch], dg2[t_bunch] = XPCS.get_g2(itime*Lbin, np.array(G2t[NfXbunch*n:NfXbunch*(n+1), NfXbunch*n:NfXbunch*(n+1)]), cython=False)
    else:         t[t_bunch], g2[t_bunch], dg2[t_bunch] = XPCS.get_g2(itime*Lbin, np.array(G2t), cython=False)
    t_mt[t_bunch], g2_mt[t_bunch] = XPCS.get_g2mt_fromling2(itime*Lbin, g2[t_bunch])
# Out:
# Computing g2 (using cython code)...
# Done! (elapsed time = 0.0 s)
#
# Computing g2 (using cython code)...
# Done! (elapsed time = 0.0 s)
#
# Computing g2 (using cython code)...
# Done! (elapsed time = 0.0 s)
#
# Computing g2 (using cython code)...
# Done! (elapsed time = 0.0 s)

# %%
##################
t1_fit = 0
t2_fit = 1e100
##################

#####################################################
model = lm.Model(decorrelation_f)
params = lm.Parameters()
params.add('tau', value=1000, min=0, max=1e6)
params.add('beta', value=1, min=0, max=2)
params.add('c', value=.02, min=0, max=1)
#params.add('y0', value=1, min=0, max=2)
params.add('y0', value=1.015, vary=False)
#####################################################
 
plt.figure(figsize=(10,5))
g2_fit = pd.DataFrame(columns=['Q', 'dQ', 'tau', 'beta', 'c', 'y0', 'dtau', 'dbeta', 'dc', 'dy0'])
g2_fit.index.name = 't'
for i,k in enumerate(g2.keys()):
    plt.scatter(t[k], g2[k], s=1,  c='C'+str(i), label = str(k)+'s')
    plt.scatter(t_mt[k], g2_mt[k], c='C'+str(i), label=str(k)+'s')
    plt.scatter(t_mt[k], g2_mt[k], c='black', label=str(k)+'s')

    x = t[k] [(t1_fit<t[k])*(t[k]<t2_fit)]
    y = g2[k][(t1_fit<t[k])*(t[k]<t2_fit)]
    x = t_mt[k] [(t1_fit<t_mt[k])*(t_mt[k]<t2_fit)]
    y = g2_mt[k][(t1_fit<t_mt[k])*(t_mt[k]<t2_fit)]
    fit = model.fit(y, params, t=x)
    g2_fit.loc[k] = [Q, dq, fit.params['tau'].value, fit.params['beta'].value, fit.params['c'].value, fit.params['y0'].value, fit.params['tau'].stderr, fit.params['beta'].stderr, fit.params['c'].stderr, fit.params['y0'].stderr]

    x = np.arange(np.min(t[k]), np.max(t[k]), 1e-2)
    y = decorrelation_f(x, *g2_fit.loc[k].values[2:6])
    plt.plot(x, y,)

plt.xlabel('t [s]')
plt.ylabel('g2')
plt.xscale('log')
plt.ylim(1, 1.05)
#plt.legend()
plt.show()

if Nbunch == 1:
    display(fit.params)
else:
    plt.figure(figsize=(10,5))
    plt.title('tau')
    plt.errorbar(g2_fit.index, g2_fit.tau,  yerr=g2_fit.dtau, fmt='o')
    plt.xlabel('t [s]')
    plt.ylabel('tau [s]')
    plt.xlim(0)
    plt.tight_layout(); plt.show()

    plt.figure(figsize=(10,5))
    plt.title('beta')
    plt.errorbar(g2_fit.index, g2_fit.beta,  yerr=g2_fit.dbeta, fmt='o')
    plt.xlabel('t [s]')
    plt.ylabel('beta')
    plt.xlim(0)
    plt.tight_layout(); plt.show()

    plt.figure(figsize=(10,5))
    plt.title('c')
    plt.errorbar(g2_fit.index, g2_fit.c,  yerr=g2_fit.dc, fmt='o')
    plt.xlabel('t [s]')
    plt.ylabel('c')
    plt.xlim(0)
    plt.tight_layout(); plt.show()

    plt.figure(figsize=(10,5))
    plt.title('y0')
    plt.errorbar(g2_fit.index, g2_fit.y0,  yerr=g2_fit.dy0, fmt='o')
    plt.xlabel('t [s]')
    plt.ylabel('y0')
    plt.tight_layout(); plt.show()
# Out:
# /data/visitor/hc6211/id10-coh/20250527/miniconda3/envs/XPCSenv_test/lib/python3.13/site-packages/uncertainties/core.py:1024: UserWarning: Using UFloat objects with std_dev==0 may give unexpected results.
#   warn("Using UFloat objects with std_dev==0 may give unexpected results.")
# /data/visitor/hc6211/id10-coh/20250527/miniconda3/envs/XPCSenv_test/lib/python3.13/site-packages/uncertainties/core.py:1024: UserWarning: Using UFloat objects with std_dev==0 may give unexpected results.
#   warn("Using UFloat objects with std_dev==0 may give unexpected results.")
# /data/visitor/hc6211/id10-coh/20250527/miniconda3/envs/XPCSenv_test/lib/python3.13/site-packages/uncertainties/core.py:1024: UserWarning: Using UFloat objects with std_dev==0 may give unexpected results.
#   warn("Using UFloat objects with std_dev==0 may give unexpected results.")
# /data/visitor/hc6211/id10-coh/20250527/miniconda3/envs/XPCSenv_test/lib/python3.13/site-packages/uncertainties/core.py:1024: UserWarning: Using UFloat objects with std_dev==0 may give unexpected results.
#   warn("Using UFloat objects with std_dev==0 may give unexpected results.")

# %% [markdown]
# ### Linear by dose

# %%
t_ff = e4m_data.shape[0]*itime
print('#############################')
print('Nff =    =',e4m_data.shape[0], ' =>  t_ff =', t_ff)
print('#############################\n')
# Out:
# #############################
# Nff =    = 13087327  =>  t_ff = 14396.059700000002
# #############################

# %%
########################################
N_segments = 3
tt = np.linspace(0, int(t_ff), N_segments)
########################################

t_segments = [(tt[i], tt[i+1]) for i in range(len(tt)-1)]
Nf_segments =  [(int(t_segments[i][0]//itime), int(t_segments[i][1]//itime)) for i in range(len(t_segments))]

# %%
from contextlib import redirect_stdout
import io

###################
Lbin = 1000
bin2dense = False
mask = None
###################

t_g2, g2, dg2= {}, {}, {}
for i in tqdm(range(len(Nf_segments))):
    with redirect_stdout(io.StringIO()):
        Nfi = Nf_segments[i][0]
        Nff = Nf_segments[i][1]
        G2t = XPCS.get_G2t(e4m_data, mask=mask, Nfi=Nfi, Nff=Nff, Lbin=Lbin, bin2dense=bin2dense)

        t_bunch = Nfi*itime + (Nff-Nfi)/2*itime
        t_g2[t_bunch], g2[t_bunch], dg2[t_bunch] = XPCS.get_g2(itime*Lbin, np.array(G2t), cython=False)
np.savez(g2_folder+'g2_'+sample_name+'_'+str(Ndataset).zfill(4)+'_'+str(Nscan).zfill(4)+'_Q='+str(Q)+'_dq='+str(dq), t_g2=t_g2, g2=g2)
# Out:
# 100%|██████████| 2/2 [00:40<00:00, 20.44s/it]

# %%
##################
t1_fit = 0
t2_fit = 1e3
##################

#####################################################
model = lm.Model(decorrelation_f)
params = lm.Parameters()
params.add('tau', value=1000, min=0, max=1e6)
params.add('beta', value=1, min=0, max=2)
params.add('c', value=.02, min=0, max=1)
#params.add('y0', value=1, min=0, max=2)
params.add('y0', value=1., vary=False)
#####################################################
 
plt.figure(figsize=(10,5))
g2_fit = pd.DataFrame(columns=['Q', 'dQ', 'tau', 'beta', 'c', 'y0', 'dtau', 'dbeta', 'dc', 'dy0'])
g2_fit.index.name = 't'
for i,k in enumerate(g2.keys()):
    plt.scatter(t_g2[k], g2[k], s=1,  c='C'+str(i), label = str(k)+'s')
    t_mt, g2_mt = XPCS.get_g2mt_fromling2(itime*Lbin, g2[k])
    plt.scatter(t_mt, g2_mt, c='C'+str(i), label=str(k)+'s')

    x = t_g2[k] [(t1_fit<t_g2[k])*(t_g2[k]<t2_fit)]
    y = g2[k][(t1_fit<t_g2[k])*(t_g2[k]<t2_fit)]
    fit = model.fit(y, params, t=x)
    g2_fit.loc[k] = [Q, dq, fit.params['tau'].value, fit.params['beta'].value, fit.params['c'].value, fit.params['y0'].value, fit.params['tau'].stderr, fit.params['beta'].stderr, fit.params['c'].stderr, fit.params['y0'].stderr]

    x = np.arange(np.min(t_g2[k])/2, np.max(t_g2[k])*2, 1e-2)
    y = decorrelation_f(x, *g2_fit.loc[k].values[2:6])
    plt.plot(x, y,)

g2_fit.to_csv(g2fit_folder+'g2fit_'+sample_name+'_'+str(Ndataset).zfill(4)+'_'+str(Nscan).zfill(4)+'_Q='+str(Q)+'_dq='+str(dq)+'.csv')

plt.xlabel('t [s]')
plt.ylabel('g2')
plt.xscale('log')
plt.ylim(1, 1.06)
#plt.legend()
plt.tight_layout(); plt.show()

plt.figure(figsize=(10,5))
plt.title('tau')
plt.errorbar(g2_fit.index, g2_fit.tau,  yerr=g2_fit.dtau, fmt='o')
plt.xlabel('t [s]')
plt.ylabel('tau [s]')
plt.xlim(0)
plt.tight_layout(); plt.show()

plt.figure(figsize=(10,5))
plt.title('beta')
plt.errorbar(g2_fit.index, g2_fit.beta,  yerr=g2_fit.dbeta, fmt='o')
plt.xlabel('t [s]')
plt.ylabel('beta')
plt.xlim(0)
plt.tight_layout(); plt.show()

plt.figure(figsize=(10,5))
plt.title('c')
plt.errorbar(g2_fit.index, g2_fit.c,  yerr=g2_fit.dc, fmt='o')
plt.xlabel('t [s]')
plt.ylabel('c')
plt.xlim(0)
plt.tight_layout(); plt.show()

plt.figure(figsize=(10,5))
plt.title('y0')
plt.errorbar(g2_fit.index, g2_fit.y0,  yerr=g2_fit.dy0, fmt='o')
plt.xlabel('t [s]')
plt.ylabel('y0')
plt.tight_layout(); plt.show()
# Out:
# /data/visitor/hc6211/id10-coh/20250527/miniconda3/envs/XPCSenv_test/lib/python3.13/site-packages/uncertainties/core.py:1024: UserWarning: Using UFloat objects with std_dev==0 may give unexpected results.
#   warn("Using UFloat objects with std_dev==0 may give unexpected results.")
# /data/visitor/hc6211/id10-coh/20250527/miniconda3/envs/XPCSenv_test/lib/python3.13/site-packages/uncertainties/core.py:1024: UserWarning: Using UFloat objects with std_dev==0 may give unexpected results.
#   warn("Using UFloat objects with std_dev==0 may give unexpected results.")
# Exception ignored in: <function ResourceTracker.__del__ at 0x7fa746773c40>
# Traceback (most recent call last):
#   File "/data/visitor/hc6211/id10-coh/20250527/miniconda3/envs/XPCSenv_test/lib/python3.13/multiprocessing/resource_tracker.py", line 82, in __del__
#   File "/data/visitor/hc6211/id10-coh/20250527/miniconda3/envs/XPCSenv_test/lib/python3.13/multiprocessing/resource_tracker.py", line 91, in _stop
#   File "/data/visitor/hc6211/id10-coh/20250527/miniconda3/envs/XPCSenv_test/lib/python3.13/multiprocessing/resource_tracker.py", line 116, in _stop_locked
# ChildProcessError: [Errno 10] No child processes
# Exception ignored in: <function ResourceTracker.__del__ at 0x7fd7618bfc40>
# Traceback (most recent call last):
#   File "/data/visitor/hc6211/id10-coh/20250527/miniconda3/envs/XPCSenv_test/lib/python3.13/multiprocessing/resource_tracker.py", line 82, in __del__
#   File "/data/visitor/hc6211/id10-coh/20250527/miniconda3/envs/XPCSenv_test/lib/python3.13/multiprocessing/resource_tracker.py", line 91, in _stop
#   File "/data/visitor/hc6211/id10-coh/20250527/miniconda3/envs/XPCSenv_test/lib/python3.13/multiprocessing/resource_tracker.py", line 116, in _stop_locked
# ChildProcessError: [Errno 10] No child processes
# Exception ignored in: <function ResourceTracker.__del__ at 0x7f4989d63c40>
# Traceback (most recent call last):
#   File "/data/visitor/hc6211/id10-coh/20250527/miniconda3/envs/XPCSenv_test/lib/python3.13/multiprocessing/resource_tracker.py", line 82, in __del__
#   File "/data/visitor/hc6211/id10-coh/20250527/miniconda3/envs/XPCSenv_test/lib/python3.13/multiprocessing/resource_tracker.py", line 91, in _stop
#   File "/data/visitor/hc6211/id10-coh/20250527/miniconda3/envs/XPCSenv_test/lib/python3.13/multiprocessing/resource_tracker.py", line 116, in _stop_locked
# ChildProcessError: [Errno 10] No child processes
# Exception ignored in: <function ResourceTracker.__del__ at 0x7fde150f7c40>
# Traceback (most recent call last):
#   File "/data/visitor/hc6211/id10-coh/20250527/miniconda3/envs/XPCSenv_test/lib/python3.13/multiprocessing/resource_tracker.py", line 82, in __del__
#   File "/data/visitor/hc6211/id10-coh/20250527/miniconda3/envs/XPCSenv_test/lib/python3.13/multiprocessing/resource_tracker.py", line 91, in _stop
#   File "/data/visitor/hc6211/id10-coh/20250527/miniconda3/envs/XPCSenv_test/lib/python3.13/multiprocessing/resource_tracker.py", line 116, in _stop_locked
# ChildProcessError: [Errno 10] No child processes
# Exception ignored in: <function ResourceTracker.__del__ at 0x7fe865513c40>
# Traceback (most recent call last):
#   File "/data/visitor/hc6211/id10-coh/20250527/miniconda3/envs/XPCSenv_test/lib/python3.13/multiprocessing/resource_tracker.py", line 82, in __del__
#   File "/data/visitor/hc6211/id10-coh/20250527/miniconda3/envs/XPCSenv_test/lib/python3.13/multiprocessing/resource_tracker.py", line 91, in _stop
#   File "/data/visitor/hc6211/id10-coh/20250527/miniconda3/envs/XPCSenv_test/lib/python3.13/multiprocessing/resource_tracker.py", line 116, in _stop_locked
# ChildProcessError: [Errno 10] No child processes
# Exception ignored in: <function ResourceTracker.__del__ at 0x7f6900777c40>
# Traceback (most recent call last):
#   File "/data/visitor/hc6211/id10-coh/20250527/miniconda3/envs/XPCSenv_test/lib/python3.13/multiprocessing/resource_tracker.py", line 82, in __del__
#   File "/data/visitor/hc6211/id10-coh/20250527/miniconda3/envs/XPCSenv_test/lib/python3.13/multiprocessing/resource_tracker.py", line 91, in _stop
#   File "/data/visitor/hc6211/id10-coh/20250527/miniconda3/envs/XPCSenv_test/lib/python3.13/multiprocessing/resource_tracker.py", line 116, in _stop_locked
# ChildProcessError: [Errno 10] No child processes
# Exception ignored in: <function ResourceTracker.__del__ at 0x7fd5994dfc40>
# Traceback (most recent call last):
#   File "/data/visitor/hc6211/id10-coh/20250527/miniconda3/envs/XPCSenv_test/lib/python3.13/multiprocessing/resource_tracker.py", line 82, in __del__
#   File "/data/visitor/hc6211/id10-coh/20250527/miniconda3/envs/XPCSenv_test/lib/python3.13/multiprocessing/resource_tracker.py", line 91, in _stop
#   File "/data/visitor/hc6211/id10-coh/20250527/miniconda3/envs/XPCSenv_test/lib/python3.13/multiprocessing/resource_tracker.py", line 116, in _stop_locked
# ChildProcessError: [Errno 10] No child processes
# Exception ignored in: <function ResourceTracker.__del__ at 0x7f35620f3c40>
# Traceback (most recent call last):
#   File "/data/visitor/hc6211/id10-coh/20250527/miniconda3/envs/XPCSenv_test/lib/python3.13/multiprocessing/resource_tracker.py", line 82, in __del__
#   File "/data/visitor/hc6211/id10-coh/20250527/miniconda3/envs/XPCSenv_test/lib/python3.13/multiprocessing/resource_tracker.py", line 91, in _stop
#   File "/data/visitor/hc6211/id10-coh/20250527/miniconda3/envs/XPCSenv_test/lib/python3.13/multiprocessing/resource_tracker.py", line 116, in _stop_locked
# ChildProcessError: [Errno 10] No child processes
# Exception ignored in: <function ResourceTracker.__del__ at 0x7f9146673c40>
# Traceback (most recent call last):
#   File "/data/visitor/hc6211/id10-coh/20250527/miniconda3/envs/XPCSenv_test/lib/python3.13/multiprocessing/resource_tracker.py", line 82, in __del__
#   File "/data/visitor/hc6211/id10-coh/20250527/miniconda3/envs/XPCSenv_test/lib/python3.13/multiprocessing/resource_tracker.py", line 91, in _stop
#   File "/data/visitor/hc6211/id10-coh/20250527/miniconda3/envs/XPCSenv_test/lib/python3.13/multiprocessing/resource_tracker.py", line 116, in _stop_locked
# ChildProcessError: [Errno 10] No child processes
# Exception ignored in: <function ResourceTracker.__del__ at 0x7f31a8fcfc40>
# Traceback (most recent call last):
#   File "/data/visitor/hc6211/id10-coh/20250527/miniconda3/envs/XPCSenv_test/lib/python3.13/multiprocessing/resource_tracker.py", line 82, in __del__
#   File "/data/visitor/hc6211/id10-coh/20250527/miniconda3/envs/XPCSenv_test/lib/python3.13/multiprocessing/resource_tracker.py", line 91, in _stop
#   File "/data/visitor/hc6211/id10-coh/20250527/miniconda3/envs/XPCSenv_test/lib/python3.13/multiprocessing/resource_tracker.py", line 116, in _stop_locked
# ChildProcessError: [Errno 10] No child processes
# Exception ignored in: <function ResourceTracker.__del__ at 0x7f47806cbc40>
# Traceback (most recent call last):
#   File "/data/visitor/hc6211/id10-coh/20250527/miniconda3/envs/XPCSenv_test/lib/python3.13/multiprocessing/resource_tracker.py", line 82, in __del__
#   File "/data/visitor/hc6211/id10-coh/20250527/miniconda3/envs/XPCSenv_test/lib/python3.13/multiprocessing/resource_tracker.py", line 91, in _stop
#   File "/data/visitor/hc6211/id10-coh/20250527/miniconda3/envs/XPCSenv_test/lib/python3.13/multiprocessing/resource_tracker.py", line 116, in _stop_locked
# ChildProcessError: [Errno 10] No child processes
# Exception ignored in: <function ResourceTracker.__del__ at 0x7f3824b6fc40>
# Traceback (most recent call last):
#   File "/data/visitor/hc6211/id10-coh/20250527/miniconda3/envs/XPCSenv_test/lib/python3.13/multiprocessing/resource_tracker.py", line 82, in __del__
#   File "/data/visitor/hc6211/id10-coh/20250527/miniconda3/envs/XPCSenv_test/lib/python3.13/multiprocessing/resource_tracker.py", line 91, in _stop
#   File "/data/visitor/hc6211/id10-coh/20250527/miniconda3/envs/XPCSenv_test/lib/python3.13/multiprocessing/resource_tracker.py", line 116, in _stop_locked
# ChildProcessError: [Errno 10] No child processes
# Exception ignored in: <function ResourceTracker.__del__ at 0x7f8b83cefc40>
# Traceback (most recent call last):
#   File "/data/visitor/hc6211/id10-coh/20250527/miniconda3/envs/XPCSenv_test/lib/python3.13/multiprocessing/resource_tracker.py", line 82, in __del__
#   File "/data/visitor/hc6211/id10-coh/20250527/miniconda3/envs/XPCSenv_test/lib/python3.13/multiprocessing/resource_tracker.py", line 91, in _stop
#   File "/data/visitor/hc6211/id10-coh/20250527/miniconda3/envs/XPCSenv_test/lib/python3.13/multiprocessing/resource_tracker.py", line 116, in _stop_locked
# ChildProcessError: [Errno 10] No child processes
# Exception ignored in: <function ResourceTracker.__del__ at 0x7f763d7afc40>
# Traceback (most recent call last):
#   File "/data/visitor/hc6211/id10-coh/20250527/miniconda3/envs/XPCSenv_test/lib/python3.13/multiprocessing/resource_tracker.py", line 82, in __del__
#   File "/data/visitor/hc6211/id10-coh/20250527/miniconda3/envs/XPCSenv_test/lib/python3.13/multiprocessing/resource_tracker.py", line 91, in _stop
#   File "/data/visitor/hc6211/id10-coh/20250527/miniconda3/envs/XPCSenv_test/lib/python3.13/multiprocessing/resource_tracker.py", line 116, in _stop_locked
# ChildProcessError: [Errno 10] No child processes
# Exception ignored in: <function ResourceTracker.__del__ at 0x7f285fdb3c40>
# Traceback (most recent call last):
#   File "/data/visitor/hc6211/id10-coh/20250527/miniconda3/envs/XPCSenv_test/lib/python3.13/multiprocessing/resource_tracker.py", line 82, in __del__
#   File "/data/visitor/hc6211/id10-coh/20250527/miniconda3/envs/XPCSenv_test/lib/python3.13/multiprocessing/resource_tracker.py", line 91, in _stop
#   File "/data/visitor/hc6211/id10-coh/20250527/miniconda3/envs/XPCSenv_test/lib/python3.13/multiprocessing/resource_tracker.py", line 116, in _stop_locked
# ChildProcessError: [Errno 10] No child processes
# Exception ignored in: <function ResourceTracker.__del__ at 0x7efdb1363c40>
# Traceback (most recent call last):
#   File "/data/visitor/hc6211/id10-coh/20250527/miniconda3/envs/XPCSenv_test/lib/python3.13/multiprocessing/resource_tracker.py", line 82, in __del__
#   File "/data/visitor/hc6211/id10-coh/20250527/miniconda3/envs/XPCSenv_test/lib/python3.13/multiprocessing/resource_tracker.py", line 91, in _stop
#   File "/data/visitor/hc6211/id10-coh/20250527/miniconda3/envs/XPCSenv_test/lib/python3.13/multiprocessing/resource_tracker.py", line 116, in _stop_locked
# ChildProcessError: [Errno 10] No child processes
# Exception ignored in: <function ResourceTracker.__del__ at 0x7f85f0b8bc40>
# Traceback (most recent call last):
#   File "/data/visitor/hc6211/id10-coh/20250527/miniconda3/envs/XPCSenv_test/lib/python3.13/multiprocessing/resource_tracker.py", line 82, in __del__
#   File "/data/visitor/hc6211/id10-coh/20250527/miniconda3/envs/XPCSenv_test/lib/python3.13/multiprocessing/resource_tracker.py", line 91, in _stop
#   File "/data/visitor/hc6211/id10-coh/20250527/miniconda3/envs/XPCSenv_test/lib/python3.13/multiprocessing/resource_tracker.py", line 116, in _stop_locked
# ChildProcessError: [Errno 10] No child processes
# Exception ignored in: <function ResourceTracker.__del__ at 0x7f221b277c40>
# Traceback (most recent call last):
#   File "/data/visitor/hc6211/id10-coh/20250527/miniconda3/envs/XPCSenv_test/lib/python3.13/multiprocessing/resource_tracker.py", line 82, in __del__
#   File "/data/visitor/hc6211/id10-coh/20250527/miniconda3/envs/XPCSenv_test/lib/python3.13/multiprocessing/resource_tracker.py", line 91, in _stop
#   File "/data/visitor/hc6211/id10-coh/20250527/miniconda3/envs/XPCSenv_test/lib/python3.13/multiprocessing/resource_tracker.py", line 116, in _stop_locked
# ChildProcessError: [Errno 10] No child processes
# Exception ignored in: <function ResourceTracker.__del__ at 0x7fd8d6723c40>
# Traceback (most recent call last):
#   File "/data/visitor/hc6211/id10-coh/20250527/miniconda3/envs/XPCSenv_test/lib/python3.13/multiprocessing/resource_tracker.py", line 82, in __del__
#   File "/data/visitor/hc6211/id10-coh/20250527/miniconda3/envs/XPCSenv_test/lib/python3.13/multiprocessing/resource_tracker.py", line 91, in _stop
#   File "/data/visitor/hc6211/id10-coh/20250527/miniconda3/envs/XPCSenv_test/lib/python3.13/multiprocessing/resource_tracker.py", line 116, in _stop_locked
# ChildProcessError: [Errno 10] No child processes
# Exception ignored in: <function ResourceTracker.__del__ at 0x7f580c1b7c40>
# Traceback (most recent call last):
#   File "/data/visitor/hc6211/id10-coh/20250527/miniconda3/envs/XPCSenv_test/lib/python3.13/multiprocessing/resource_tracker.py", line 82, in __del__
#   File "/data/visitor/hc6211/id10-coh/20250527/miniconda3/envs/XPCSenv_test/lib/python3.13/multiprocessing/resource_tracker.py", line 91, in _stop
#   File "/data/visitor/hc6211/id10-coh/20250527/miniconda3/envs/XPCSenv_test/lib/python3.13/multiprocessing/resource_tracker.py", line 116, in _stop_locked
# ChildProcessError: [Errno 10] No child processes
# Exception ignored in: <function ResourceTracker.__del__ at 0x7fe2901b7c40>
# Traceback (most recent call last):
#   File "/data/visitor/hc6211/id10-coh/20250527/miniconda3/envs/XPCSenv_test/lib/python3.13/multiprocessing/resource_tracker.py", line 82, in __del__
#   File "/data/visitor/hc6211/id10-coh/20250527/miniconda3/envs/XPCSenv_test/lib/python3.13/multiprocessing/resource_tracker.py", line 91, in _stop
#   File "/data/visitor/hc6211/id10-coh/20250527/miniconda3/envs/XPCSenv_test/lib/python3.13/multiprocessing/resource_tracker.py", line 116, in _stop_locked
# ChildProcessError: [Errno 10] No child processes
# Exception ignored in: <function ResourceTracker.__del__ at 0x7f5e3640fc40>
# Traceback (most recent call last):
#   File "/data/visitor/hc6211/id10-coh/20250527/miniconda3/envs/XPCSenv_test/lib/python3.13/multiprocessing/resource_tracker.py", line 82, in __del__
#   File "/data/visitor/hc6211/id10-coh/20250527/miniconda3/envs/XPCSenv_test/lib/python3.13/multiprocessing/resource_tracker.py", line 91, in _stop
#   File "/data/visitor/hc6211/id10-coh/20250527/miniconda3/envs/XPCSenv_test/lib/python3.13/multiprocessing/resource_tracker.py", line 116, in _stop_locked
# ChildProcessError: [Errno 10] No child processes
# Exception ignored in: <function ResourceTracker.__del__ at 0x7f219c70fc40>
# Traceback (most recent call last):
#   File "/data/visitor/hc6211/id10-coh/20250527/miniconda3/envs/XPCSenv_test/lib/python3.13/multiprocessing/resource_tracker.py", line 82, in __del__
#   File "/data/visitor/hc6211/id10-coh/20250527/miniconda3/envs/XPCSenv_test/lib/python3.13/multiprocessing/resource_tracker.py", line 91, in _stop
#   File "/data/visitor/hc6211/id10-coh/20250527/miniconda3/envs/XPCSenv_test/lib/python3.13/multiprocessing/resource_tracker.py", line 116, in _stop_locked
# ChildProcessError: [Errno 10] No child processes
# Exception ignored in: <function ResourceTracker.__del__ at 0x7f6e19737c40>
# Traceback (most recent call last):
#   File "/data/visitor/hc6211/id10-coh/20250527/miniconda3/envs/XPCSenv_test/lib/python3.13/multiprocessing/resource_tracker.py", line 82, in __del__
#   File "/data/visitor/hc6211/id10-coh/20250527/miniconda3/envs/XPCSenv_test/lib/python3.13/multiprocessing/resource_tracker.py", line 91, in _stop
#   File "/data/visitor/hc6211/id10-coh/20250527/miniconda3/envs/XPCSenv_test/lib/python3.13/multiprocessing/resource_tracker.py", line 116, in _stop_locked
# ChildProcessError: [Errno 10] No child processes
# Exception ignored in: <function ResourceTracker.__del__ at 0x7f588a3e7c40>
# Traceback (most recent call last):
#   File "/data/visitor/hc6211/id10-coh/20250527/miniconda3/envs/XPCSenv_test/lib/python3.13/multiprocessing/resource_tracker.py", line 82, in __del__
#   File "/data/visitor/hc6211/id10-coh/20250527/miniconda3/envs/XPCSenv_test/lib/python3.13/multiprocessing/resource_tracker.py", line 91, in _stop
#   File "/data/visitor/hc6211/id10-coh/20250527/miniconda3/envs/XPCSenv_test/lib/python3.13/multiprocessing/resource_tracker.py", line 116, in _stop_locked
# ChildProcessError: [Errno 10] No child processes
# Exception ignored in: <function ResourceTracker.__del__ at 0x7f34f2a23c40>
# Traceback (most recent call last):
#   File "/data/visitor/hc6211/id10-coh/20250527/miniconda3/envs/XPCSenv_test/lib/python3.13/multiprocessing/resource_tracker.py", line 82, in __del__
#   File "/data/visitor/hc6211/id10-coh/20250527/miniconda3/envs/XPCSenv_test/lib/python3.13/multiprocessing/resource_tracker.py", line 91, in _stop
#   File "/data/visitor/hc6211/id10-coh/20250527/miniconda3/envs/XPCSenv_test/lib/python3.13/multiprocessing/resource_tracker.py", line 116, in _stop_locked
# ChildProcessError: [Errno 10] No child processes
# Exception ignored in: <function ResourceTracker.__del__ at 0x7ff753cfbc40>
# Traceback (most recent call last):
#   File "/data/visitor/hc6211/id10-coh/20250527/miniconda3/envs/XPCSenv_test/lib/python3.13/multiprocessing/resource_tracker.py", line 82, in __del__
#   File "/data/visitor/hc6211/id10-coh/20250527/miniconda3/envs/XPCSenv_test/lib/python3.13/multiprocessing/resource_tracker.py", line 91, in _stop
#   File "/data/visitor/hc6211/id10-coh/20250527/miniconda3/envs/XPCSenv_test/lib/python3.13/multiprocessing/resource_tracker.py", line 116, in _stop_locked
# ChildProcessError: [Errno 10] No child processes
# Exception ignored in: <function ResourceTracker.__del__ at 0x7fba34593c40>
# Traceback (most recent call last):
#   File "/data/visitor/hc6211/id10-coh/20250527/miniconda3/envs/XPCSenv_test/lib/python3.13/multiprocessing/resource_tracker.py", line 82, in __del__
#   File "/data/visitor/hc6211/id10-coh/20250527/miniconda3/envs/XPCSenv_test/lib/python3.13/multiprocessing/resource_tracker.py", line 91, in _stop
#   File "/data/visitor/hc6211/id10-coh/20250527/miniconda3/envs/XPCSenv_test/lib/python3.13/multiprocessing/resource_tracker.py", line 116, in _stop_locked
# ChildProcessError: [Errno 10] No child processes
# Exception ignored in: <function ResourceTracker.__del__ at 0x7f3aa1493c40>
# Traceback (most recent call last):
#   File "/data/visitor/hc6211/id10-coh/20250527/miniconda3/envs/XPCSenv_test/lib/python3.13/multiprocessing/resource_tracker.py", line 82, in __del__
#   File "/data/visitor/hc6211/id10-coh/20250527/miniconda3/envs/XPCSenv_test/lib/python3.13/multiprocessing/resource_tracker.py", line 91, in _stop
#   File "/data/visitor/hc6211/id10-coh/20250527/miniconda3/envs/XPCSenv_test/lib/python3.13/multiprocessing/resource_tracker.py", line 116, in _stop_locked
# ChildProcessError: [Errno 10] No child processes
# Exception ignored in: <function ResourceTracker.__del__ at 0x7f0a5e237c40>
# Traceback (most recent call last):
#   File "/data/visitor/hc6211/id10-coh/20250527/miniconda3/envs/XPCSenv_test/lib/python3.13/multiprocessing/resource_tracker.py", line 82, in __del__
#   File "/data/visitor/hc6211/id10-coh/20250527/miniconda3/envs/XPCSenv_test/lib/python3.13/multiprocessing/resource_tracker.py", line 91, in _stop
#   File "/data/visitor/hc6211/id10-coh/20250527/miniconda3/envs/XPCSenv_test/lib/python3.13/multiprocessing/resource_tracker.py", line 116, in _stop_locked
# ChildProcessError: [Errno 10] No child processes
# Exception ignored in: <function ResourceTracker.__del__ at 0x7f798cf9bc40>
# Traceback (most recent call last):
#   File "/data/visitor/hc6211/id10-coh/20250527/miniconda3/envs/XPCSenv_test/lib/python3.13/multiprocessing/resource_tracker.py", line 82, in __del__
#   File "/data/visitor/hc6211/id10-coh/20250527/miniconda3/envs/XPCSenv_test/lib/python3.13/multiprocessing/resource_tracker.py", line 91, in _stop
#   File "/data/visitor/hc6211/id10-coh/20250527/miniconda3/envs/XPCSenv_test/lib/python3.13/multiprocessing/resource_tracker.py", line 116, in _stop_locked
# ChildProcessError: [Errno 10] No child processes
# Exception ignored in: <function ResourceTracker.__del__ at 0x7f623d42fc40>
# Traceback (most recent call last):
#   File "/data/visitor/hc6211/id10-coh/20250527/miniconda3/envs/XPCSenv_test/lib/python3.13/multiprocessing/resource_tracker.py", line 82, in __del__
#   File "/data/visitor/hc6211/id10-coh/20250527/miniconda3/envs/XPCSenv_test/lib/python3.13/multiprocessing/resource_tracker.py", line 91, in _stop
#   File "/data/visitor/hc6211/id10-coh/20250527/miniconda3/envs/XPCSenv_test/lib/python3.13/multiprocessing/resource_tracker.py", line 116, in _stop_locked
# ChildProcessError: [Errno 10] No child processes
# Exception ignored in: <function ResourceTracker.__del__ at 0x7fb0b8173c40>
# Traceback (most recent call last):
#   File "/data/visitor/hc6211/id10-coh/20250527/miniconda3/envs/XPCSenv_test/lib/python3.13/multiprocessing/resource_tracker.py", line 82, in __del__
#   File "/data/visitor/hc6211/id10-coh/20250527/miniconda3/envs/XPCSenv_test/lib/python3.13/multiprocessing/resource_tracker.py", line 91, in _stop
#   File "/data/visitor/hc6211/id10-coh/20250527/miniconda3/envs/XPCSenv_test/lib/python3.13/multiprocessing/resource_tracker.py", line 116, in _stop_locked
# ChildProcessError: [Errno 10] No child processes
# Exception ignored in: <function ResourceTracker.__del__ at 0x7fd90759bc40>
# Traceback (most recent call last):
#   File "/data/visitor/hc6211/id10-coh/20250527/miniconda3/envs/XPCSenv_test/lib/python3.13/multiprocessing/resource_tracker.py", line 82, in __del__
#   File "/data/visitor/hc6211/id10-coh/20250527/miniconda3/envs/XPCSenv_test/lib/python3.13/multiprocessing/resource_tracker.py", line 91, in _stop
#   File "/data/visitor/hc6211/id10-coh/20250527/miniconda3/envs/XPCSenv_test/lib/python3.13/multiprocessing/resource_tracker.py", line 116, in _stop_locked
# ChildProcessError: [Errno 10] No child processes
# Exception ignored in: <function ResourceTracker.__del__ at 0x7f4b956f3c40>
# Traceback (most recent call last):
#   File "/data/visitor/hc6211/id10-coh/20250527/miniconda3/envs/XPCSenv_test/lib/python3.13/multiprocessing/resource_tracker.py", line 82, in __del__
#   File "/data/visitor/hc6211/id10-coh/20250527/miniconda3/envs/XPCSenv_test/lib/python3.13/multiprocessing/resource_tracker.py", line 91, in _stop
#   File "/data/visitor/hc6211/id10-coh/20250527/miniconda3/envs/XPCSenv_test/lib/python3.13/multiprocessing/resource_tracker.py", line 116, in _stop_locked
# ChildProcessError: [Errno 10] No child processes
# Exception ignored in: <function ResourceTracker.__del__ at 0x7f14bbdc3c40>
# Traceback (most recent call last):
#   File "/data/visitor/hc6211/id10-coh/20250527/miniconda3/envs/XPCSenv_test/lib/python3.13/multiprocessing/resource_tracker.py", line 82, in __del__
#   File "/data/visitor/hc6211/id10-coh/20250527/miniconda3/envs/XPCSenv_test/lib/python3.13/multiprocessing/resource_tracker.py", line 91, in _stop
#   File "/data/visitor/hc6211/id10-coh/20250527/miniconda3/envs/XPCSenv_test/lib/python3.13/multiprocessing/resource_tracker.py", line 116, in _stop_locked
# ChildProcessError: [Errno 10] No child processes
# Exception ignored in: <function ResourceTracker.__del__ at 0x7f5bc378bc40>
# Traceback (most recent call last):
#   File "/data/visitor/hc6211/id10-coh/20250527/miniconda3/envs/XPCSenv_test/lib/python3.13/multiprocessing/resource_tracker.py", line 82, in __del__
#   File "/data/visitor/hc6211/id10-coh/20250527/miniconda3/envs/XPCSenv_test/lib/python3.13/multiprocessing/resource_tracker.py", line 91, in _stop
#   File "/data/visitor/hc6211/id10-coh/20250527/miniconda3/envs/XPCSenv_test/lib/python3.13/multiprocessing/resource_tracker.py", line 116, in _stop_locked
# ChildProcessError: [Errno 10] No child processes
# Exception ignored in: <function ResourceTracker.__del__ at 0x7fcd3f38bc40>
# Traceback (most recent call last):
#   File "/data/visitor/hc6211/id10-coh/20250527/miniconda3/envs/XPCSenv_test/lib/python3.13/multiprocessing/resource_tracker.py", line 82, in __del__
#   File "/data/visitor/hc6211/id10-coh/20250527/miniconda3/envs/XPCSenv_test/lib/python3.13/multiprocessing/resource_tracker.py", line 91, in _stop
#   File "/data/visitor/hc6211/id10-coh/20250527/miniconda3/envs/XPCSenv_test/lib/python3.13/multiprocessing/resource_tracker.py", line 116, in _stop_locked
# ChildProcessError: [Errno 10] No child processes
# Exception ignored in: <function ResourceTracker.__del__ at 0x7f5fcd683c40>
# Traceback (most recent call last):
#   File "/data/visitor/hc6211/id10-coh/20250527/miniconda3/envs/XPCSenv_test/lib/python3.13/multiprocessing/resource_tracker.py", line 82, in __del__
#   File "/data/visitor/hc6211/id10-coh/20250527/miniconda3/envs/XPCSenv_test/lib/python3.13/multiprocessing/resource_tracker.py", line 91, in _stop
#   File "/data/visitor/hc6211/id10-coh/20250527/miniconda3/envs/XPCSenv_test/lib/python3.13/multiprocessing/resource_tracker.py", line 116, in _stop_locked
# ChildProcessError: [Errno 10] No child processes
# Exception ignored in: <function ResourceTracker.__del__ at 0x7fa1f69afc40>
# Traceback (most recent call last):
#   File "/data/visitor/hc6211/id10-coh/20250527/miniconda3/envs/XPCSenv_test/lib/python3.13/multiprocessing/resource_tracker.py", line 82, in __del__
#   File "/data/visitor/hc6211/id10-coh/20250527/miniconda3/envs/XPCSenv_test/lib/python3.13/multiprocessing/resource_tracker.py", line 91, in _stop
#   File "/data/visitor/hc6211/id10-coh/20250527/miniconda3/envs/XPCSenv_test/lib/python3.13/multiprocessing/resource_tracker.py", line 116, in _stop_locked
# ChildProcessError: [Errno 10] No child processes
# Exception ignored in: <function ResourceTracker.__del__ at 0x7f3f5fb23c40>
# Traceback (most recent call last):
#   File "/data/visitor/hc6211/id10-coh/20250527/miniconda3/envs/XPCSenv_test/lib/python3.13/multiprocessing/resource_tracker.py", line 82, in __del__
#   File "/data/visitor/hc6211/id10-coh/20250527/miniconda3/envs/XPCSenv_test/lib/python3.13/multiprocessing/resource_tracker.py", line 91, in _stop
#   File "/data/visitor/hc6211/id10-coh/20250527/miniconda3/envs/XPCSenv_test/lib/python3.13/multiprocessing/resource_tracker.py", line 116, in _stop_locked
# ChildProcessError: [Errno 10] No child processes
# Exception ignored in: <function ResourceTracker.__del__ at 0x7f3f57abbc40>
# Traceback (most recent call last):
#   File "/data/visitor/hc6211/id10-coh/20250527/miniconda3/envs/XPCSenv_test/lib/python3.13/multiprocessing/resource_tracker.py", line 82, in __del__
#   File "/data/visitor/hc6211/id10-coh/20250527/miniconda3/envs/XPCSenv_test/lib/python3.13/multiprocessing/resource_tracker.py", line 91, in _stop
#   File "/data/visitor/hc6211/id10-coh/20250527/miniconda3/envs/XPCSenv_test/lib/python3.13/multiprocessing/resource_tracker.py", line 116, in _stop_locked
# ChildProcessError: [Errno 10] No child processes
# Exception ignored in: <function ResourceTracker.__del__ at 0x7efe3b50bc40>
# Traceback (most recent call last):
#   File "/data/visitor/hc6211/id10-coh/20250527/miniconda3/envs/XPCSenv_test/lib/python3.13/multiprocessing/resource_tracker.py", line 82, in __del__
#   File "/data/visitor/hc6211/id10-coh/20250527/miniconda3/envs/XPCSenv_test/lib/python3.13/multiprocessing/resource_tracker.py", line 91, in _stop
#   File "/data/visitor/hc6211/id10-coh/20250527/miniconda3/envs/XPCSenv_test/lib/python3.13/multiprocessing/resource_tracker.py", line 116, in _stop_locked
# ChildProcessError: [Errno 10] No child processes
# Exception ignored in: <function ResourceTracker.__del__ at 0x7fa18f6e3c40>
# Traceback (most recent call last):
#   File "/data/visitor/hc6211/id10-coh/20250527/miniconda3/envs/XPCSenv_test/lib/python3.13/multiprocessing/resource_tracker.py", line 82, in __del__
#   File "/data/visitor/hc6211/id10-coh/20250527/miniconda3/envs/XPCSenv_test/lib/python3.13/multiprocessing/resource_tracker.py", line 91, in _stop
#   File "/data/visitor/hc6211/id10-coh/20250527/miniconda3/envs/XPCSenv_test/lib/python3.13/multiprocessing/resource_tracker.py", line 116, in _stop_locked
# ChildProcessError: [Errno 10] No child processes
# Exception ignored in: <function ResourceTracker.__del__ at 0x7f299636fc40>
# Traceback (most recent call last):
#   File "/data/visitor/hc6211/id10-coh/20250527/miniconda3/envs/XPCSenv_test/lib/python3.13/multiprocessing/resource_tracker.py", line 82, in __del__
#   File "/data/visitor/hc6211/id10-coh/20250527/miniconda3/envs/XPCSenv_test/lib/python3.13/multiprocessing/resource_tracker.py", line 91, in _stop
#   File "/data/visitor/hc6211/id10-coh/20250527/miniconda3/envs/XPCSenv_test/lib/python3.13/multiprocessing/resource_tracker.py", line 116, in _stop_locked
# ChildProcessError: [Errno 10] No child processes
# Exception ignored in: <function ResourceTracker.__del__ at 0x7fd2d11d7c40>
# Traceback (most recent call last):
#   File "/data/visitor/hc6211/id10-coh/20250527/miniconda3/envs/XPCSenv_test/lib/python3.13/multiprocessing/resource_tracker.py", line 82, in __del__
#   File "/data/visitor/hc6211/id10-coh/20250527/miniconda3/envs/XPCSenv_test/lib/python3.13/multiprocessing/resource_tracker.py", line 91, in _stop
#   File "/data/visitor/hc6211/id10-coh/20250527/miniconda3/envs/XPCSenv_test/lib/python3.13/multiprocessing/resource_tracker.py", line 116, in _stop_locked
# ChildProcessError: [Errno 10] No child processes
# Exception ignored in: <function ResourceTracker.__del__ at 0x7fa6952f3c40>
# Traceback (most recent call last):
#   File "/data/visitor/hc6211/id10-coh/20250527/miniconda3/envs/XPCSenv_test/lib/python3.13/multiprocessing/resource_tracker.py", line 82, in __del__
#   File "/data/visitor/hc6211/id10-coh/20250527/miniconda3/envs/XPCSenv_test/lib/python3.13/multiprocessing/resource_tracker.py", line 91, in _stop
#   File "/data/visitor/hc6211/id10-coh/20250527/miniconda3/envs/XPCSenv_test/lib/python3.13/multiprocessing/resource_tracker.py", line 116, in _stop_locked
# ChildProcessError: [Errno 10] No child processes
# Exception ignored in: <function ResourceTracker.__del__ at 0x7f2643387c40>
# Traceback (most recent call last):
#   File "/data/visitor/hc6211/id10-coh/20250527/miniconda3/envs/XPCSenv_test/lib/python3.13/multiprocessing/resource_tracker.py", line 82, in __del__
#   File "/data/visitor/hc6211/id10-coh/20250527/miniconda3/envs/XPCSenv_test/lib/python3.13/multiprocessing/resource_tracker.py", line 91, in _stop
#   File "/data/visitor/hc6211/id10-coh/20250527/miniconda3/envs/XPCSenv_test/lib/python3.13/multiprocessing/resource_tracker.py", line 116, in _stop_locked
# ChildProcessError: [Errno 10] No child processes
# Exception ignored in: <function ResourceTracker.__del__ at 0x7fd2489e3c40>
# Traceback (most recent call last):
#   File "/data/visitor/hc6211/id10-coh/20250527/miniconda3/envs/XPCSenv_test/lib/python3.13/multiprocessing/resource_tracker.py", line 82, in __del__
#   File "/data/visitor/hc6211/id10-coh/20250527/miniconda3/envs/XPCSenv_test/lib/python3.13/multiprocessing/resource_tracker.py", line 91, in _stop
#   File "/data/visitor/hc6211/id10-coh/20250527/miniconda3/envs/XPCSenv_test/lib/python3.13/multiprocessing/resource_tracker.py", line 116, in _stop_locked
# ChildProcessError: [Errno 10] No child processes
# Exception ignored in: <function ResourceTracker.__del__ at 0x7fb80a44bc40>
# Traceback (most recent call last):
#   File "/data/visitor/hc6211/id10-coh/20250527/miniconda3/envs/XPCSenv_test/lib/python3.13/multiprocessing/resource_tracker.py", line 82, in __del__
#   File "/data/visitor/hc6211/id10-coh/20250527/miniconda3/envs/XPCSenv_test/lib/python3.13/multiprocessing/resource_tracker.py", line 91, in _stop
#   File "/data/visitor/hc6211/id10-coh/20250527/miniconda3/envs/XPCSenv_test/lib/python3.13/multiprocessing/resource_tracker.py", line 116, in _stop_locked
# ChildProcessError: [Errno 10] No child processes

# %% [markdown]
# ### Multi-tau Correlation (TO BE REORDER!!!)

# %%
XPCS.print_Nf_choices(len(scan['fast_timer_period']))
# Out:
#        Nf = 2504444    =>    log2(Nf) = 21.26
# ----------------------------------------------------
#   reduced Nf  dense depth (2^x)  thrown frames %  thrown frames
# 0      2**21                 20             16.3         407292
# 1    9*2**18                 17              6.0         145148
# 2   19*2**17                 16              1.0          14076
# 3  305*2**13                 12              0.0           5884
# 4  611*2**12                 11              0.0           1788
# ----------------------------------------------------

# %%
##### INPUTS #####
Nfi = 0
Nff = 0 +2**21
sparse_depth = 13
dense_depth = 20
##################

G2tmt = XPCS.get_G2tmt_4sparse(e4m_data, sparse_depth, dense_depth, Nfi, Nff, mask=None)
#G2tmt = XPCS.get_G2tmt_4sparse_bypartialloading(RAW_folder, sample_name, Ndataset, Nscan, sparse_depth, dense_depth, Nfi, Nff, mask = load_mask, n_jobs=1)
t_mt, g2_mt, dg2_mt = XPCS.get_g2mt(itime, G2tmt)
# Out:
# Loading frames ...
# Done! (elapsed time = 1.5 s)
# 	 | 2097152 frames X 192980 pixels
# 	 | sparsity = 4.12e-04
# 	 | memory usage (sparse.csr_array @ float32) = 1.881 GB
# Computing sparse multitau G2t...
# 100%|██████████| 256/256 [00:40<00:00,  6.38it/s]
# Done! (elapsed time = 40.18 s)
# Computing dense multitau G2t...
# 100%|██████████| 7/7 [00:00<00:00, 60.13it/s]
# Done! (elapsed time = 0.12 s)

# %%
############################
vmin, vmax = 1.005, 1.017
lower_mt = 6
filter_layer = 12
############################

XPCS.plot_G2tmt(G2tmt, itime, vmin, vmax, yscale='log', lower_mt=lower_mt, filter_layer=filter_layer)

# %%
cut1 = XPCS.cut_G2tmt(itime, G2tmt, tmin=None, tmax=3000)
cut2 = XPCS.cut_G2tmt(itime, G2tmt, tmin=3000, tmax=6000)
cut3 = XPCS.cut_G2tmt(itime, G2tmt, tmin=6000, tmax=15000)
t_mt_1, g2_mt_1, dg2_mt_1 = XPCS.get_g2mt(itime, cut1)
t_mt_2, g2_mt_2, dg2_mt_2 = XPCS.get_g2mt(itime, cut2)
t_mt_3, g2_mt_3, dg2_mt_3 = XPCS.get_g2mt(itime, cut3)

# %%
##################
t1_fit = 1
t2_fit = 1e8
##################

plt.figure(figsize=(10,5))
plt.errorbar(t_mt, g2_mt, yerr=dg2_mt, fmt='o', label='g2')
#plt.errorbar(t_mt_1, g2_mt_1, yerr=dg2_mt_1, fmt='o', label='CUT1')
#plt.errorbar(t_mt_2, g2_mt_2, yerr=dg2_mt_2, fmt='o', label='CUT2')
#plt.errorbar(t_mt_3, g2_mt_3, yerr=dg2_mt_3, fmt='o', label='CUT3')


popt, pcov = curve_fit(decorrelation_f, t_mt[(t1_fit<t_mt)*(t_mt<t2_fit)], g2_mt[(t1_fit<t_mt)*(t_mt<t2_fit)], p0=[1000, .8, .04, 1], bounds=([0, 0, 0, .9999], [np.inf, np.inf, np.inf, 1.1]))
x = np.arange(np.min(t_mt), np.max(t_mt)+1e5, 1e-2)
y = decorrelation_f(x, *popt)
plt.plot(x, y,)

plt.xlabel('t [s]')
plt.ylabel('g2')
plt.xscale('log')
plt.legend()
plt.show()


print(f'tau = {popt[0]} +/- {np.sqrt(pcov[0,0])}')
print(f'beta = {popt[1]} +/- {np.sqrt(pcov[1,1])}')
print(f'c = {popt[2]} +/- {np.sqrt(pcov[2,2])}')
print(f'y0 = {popt[3]} +/- {np.sqrt(pcov[3,3])}')
# Out:
# tau = 2278.4462895214124 +/- 980.3358234853137
# beta = 0.8327289412512385 +/- 0.0798632634225064
# c = 0.012514664192682625 +/- 0.0027602589650978534
# y0 = 0.9999000000000001 +/- 0.002718059032489621
